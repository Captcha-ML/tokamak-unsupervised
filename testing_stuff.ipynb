# %%
from helpers import *
import numpy as np

# %%
X, y, desired_columns = get_training_data(include_time = False, include_shotnumber = False, shot_indices = [0])

# %%
y = np.ones(y.shape[0])
y[0] = 2
y
# Out:
# array([2., 1., 1., ..., 1., 1., 1.])

# %%
draw_reduced_space(perform_pca(X, n_components = 3), y, n_components = 3, title = "This is my 2D or 3D dimensionality reduction test")

# %%
draw_reduced_space(perform_pca(X, n_components = 3), y, n_components = 3, title = "This is my 2D or 3D dimensionality reduction test")

# %%
import unittest
from helpers import draw_reduced_space  # Import your function from your module
import numpy as np

# %%
# Test for an invalid number of components
components = np.random.rand(100, 2)
s_y = np.random.randint(0, 3, 100)
title = "Invalid Components Test"

# Ensure a message is printed

draw_reduced_space(components, s_y, n_components=2, title=title)

# %%
components = np.random.rand(100, 2)
s_y = np.random.choice([0, 2], size=100)  # Simulate "L-mode" (0) and "ELMy H-mode" (2)
title = "Test 2D Plot (L-mode & ELMy H-mode)"
legend_labels = ['L-mode', 'ELMy H-mode']

# Ensure no errors are raised
draw_reduced_space(components, s_y, n_components=2)
